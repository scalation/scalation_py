# %%
import numpy as np
from util.getmetrics import getmetrics
from modeling.statmodeling.RandomWalk import RandomWalk
from modeling.statmodeling.MeanModel import MeanModel
from modeling.statmodeling.SimpleMovingAverage import SimpleMovingAverage

# %%
MO = 'new_deaths'
horizon = 4
actual, forecasts = RandomWalk(file_name = 'datasets/covid/OWID_weekly.csv',
                                training_ratio = 0.5, horizon = horizon, main_output = MO,
                                normalization = False)
print("Test set metrics {}".format(MO))
for i in range(horizon):
    mse, mae, smape = getmetrics(np.expand_dims(actual[:,i], axis = -1), np.expand_dims(forecasts[:,i], axis = -1))
    print('N:{}, MSE:{}, MAE:{}, sMAPE:{}'.format(len(actual), mse, mae, smape))
# Out:
# /Users/maldosari/PycharmProjects/scalation_py/modeling/statmodeling/RandomWalk.py:49: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   actual[i, j] = data_MO.iloc[train_size + i + j, :]
# /Users/maldosari/PycharmProjects/scalation_py/modeling/statmodeling/RandomWalk.py:50: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts[i, j] = data_MO.iloc[train_size + i - 1,
# Test set metrics new_deaths
# N:82, MSE:1433434.1463414633, MAE:807.439024390244, sMAPE:15.13975813673161
# N:82, MSE:3401605.3170731706, MAE:1160.3902439024391, sMAPE:19.464675699340354
# N:82, MSE:5992895.6707317075, MAE:1500.1341463414635, sMAPE:24.743412923646286
# N:82, MSE:9274645.780487806, MAE:1821.8292682926829, sMAPE:30.11031037716555

# %%
MO = 'new_deaths'
horizon = 4
actual, forecasts = MeanModel(file_name = 'datasets/covid/OWID_weekly.csv',
                                training_ratio = 0.5, horizon = horizon, main_output = MO,
                                normalization = False)
print("Test set metrics {}".format(MO))
for i in range(horizon):
    mse, mae, smape = getmetrics(np.expand_dims(actual[:,i], axis = -1), np.expand_dims(forecasts[:,i], axis = -1))
    print('N:{}, MSE:{}, MAE:{}, sMAPE:{}'.format(len(actual), mse, mae, smape))

# %%
MO = 'new_deaths'
horizon = 4
actual, forecasts = SimpleMovingAverage(file_name = 'datasets/covid/OWID_weekly.csv',
                                training_ratio = 0.5, horizon = horizon, main_output = MO,
                                normalization = False, window = 50)
print("Test set metrics {}".format(MO))
for i in range(horizon):
    mse, mae, smape = getmetrics(np.expand_dims(actual[:,i], axis = -1), np.expand_dims(forecasts[:,i], axis = -1))
    print('N:{}, MSE:{}, MAE:{}, sMAPE:{}'.format(len(actual), mse, mae, smape))
