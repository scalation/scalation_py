# %%
import sys
import os
cwd = os.getcwd()
project_root = os.path.abspath(os.path.join(cwd, ".."))
sys.path.append(os.path.dirname(project_root))
from util.tools import dotdict
from modeling.neuralmodeling.exp.Experiments import Experiment

args = dotdict()
args.cwd = cwd
args.model_name = 'PatchTST'
args.random_seed = 10
args.seq_len = 60
args.label_len = 0
args.horizons = list(range(1, 25))
args.qof_mode = 'Single'
#args['horizons'] = [6, 12, 24, 48, 60]
#args['qof_mode'] = 'cumulative'
args.modeling_mode = 'joint'
args.e_layers = 2
args.d_layers = 1
args.d_model = 256
args.n_heads = 4
args.d_ff = 256
args.dataset_name = 'ILI'
args.target = 'ILITOTAL'

args.dropout = 0.3
args.fc_dropout = 0.3
args.head_dropout = 0.1

args.patch_len = 8
args.stride = 1
args.patch_len_dec = 1
args.stride_dec = 1
args.output_attention = False

args.learning_rate = 0.001
args.is_training = 1
args.dataset_path = '../../datasets/ili/national_illness_24.csv'
args.model_id = 'ILI'+str(args.pred_len)
args.features = 'MS'
args.factor = 5
args.enc_in = 7
args.dec_in = 7
args.c_out = 7
args.distil = False
args.activation = 'gelu'

args.train_epochs = 100
args.patience = 10
args.batch_size = 8
args.loss = 'mse'
args.lradj = 'type2'
args.use_amp = False
args.gpu = 0
args.use_multi_gpu = True
args.devices = '0'
args.use_gpu = True
args.moving_avg = 25
args.num_workers = 0
args.freq = 'h'

args.pct_start = 0.3

args.padding_patch = 'end'
args.embed = 'timeF'
args.affine = 0
args.subtract_last = 1
args.decomposition = 0
args.kernel_size = 25
args.individual = 0
args.test_flop = False

args.tf_ratio = 1.0
args.use_tf = True

args.rnn_layer_dim = 2
args.series = 1000
args.version = 'Fourier'
args.mode_select = 'random'
args.modes = 64

args.plot_eda = False 
args.transformation = 'log1p' 
args.forecast_type = 'point'
args.plot_mode = 'test_original' 
args.qof_equal_samples = True 

args.skip_insample = None 
args.training_ratio = 0.8 
args.debugging = True 
args.embed_type = 0 
args.plot_losses = True 

args.revin = True
args.subtract_last = False
args.learn_scale = False
args.plot_residuals = None 
args.residual_lag = 20 
args.cycle = 52
args.model_type = 'linear'

args.mixer_kernel_size = 8

args.decomp_method = 'dft_decomp'
args.down_sampling_layers = 2
args.down_sampling_window = 2
args.task_name = 'long_term_forecast'
args.down_sampling_method = 'avg'
args.channel_independence = 0
args.top_k = 3
args.use_norm = True
args.num_kernels = 6

args.period = 2
args.ia_layers = 1
args.attn_dropout = 0.1
args.pd_layers = 1
args.ca_layers = 1
args.stable_len = 4

args.clip_dates = True
args.start_date = '2020-04-13'
args.end_date = '2022-04-04'

args.qof_metrics = ['MSE Normalized', 
                    'MAE Normalized', 
                    'MAE Original', 
                    'sMAPE Original']

Exp = Experiment(args)
forecast_tensor_original = Exp.trainNtest()
# Out:
# Use GPU: cuda:0
# DataParallel(
#   (module): Model(
#     (model): PatchTST_backbone(
#       (revin_layer): RevIN()
#       (padding_patch_layer): ReplicationPad1d((0, 1))
#       (backbone): TSTiEncoder(
#         (W_P): Linear(in_features=8, out_features=256, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#         (encoder): TSTEncoder(
#           (layers): ModuleList(
#             (0-1): 2 x TSTEncoderLayer(
#               (self_attn): _MultiheadAttention(
#                 (W_Q): Linear(in_features=256, out_features=256, bias=True)
#                 (W_K): Linear(in_features=256, out_features=256, bias=True)
#                 (W_V): Linear(in_features=256, out_features=256, bias=True)
#                 (sdp_attn): _ScaledDotProductAttention(
#                   (attn_dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (to_out): Sequential(
#                   (0): Linear(in_features=256, out_features=256, bias=True)
#                   (1): Dropout(p=0.3, inplace=False)
#                 )
#               )
#               (dropout_attn): Dropout(p=0.3, inplace=False)
#               (norm_attn): Sequential(
#                 (0): Transpose()
#                 (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): Transpose()
#               )
#               (ff): Sequential(
#                 (0): Linear(in_features=256, out_features=256, bias=True)
#                 (1): GELU(approximate='none')
#                 (2): Dropout(p=0.3, inplace=False)
#                 (3): Linear(in_features=256, out_features=256, bias=True)
#               )
#               (dropout_ffn): Dropout(p=0.3, inplace=False)
#               (norm_ffn): Sequential(
#                 (0): Transpose()
#                 (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): Transpose()
#               )
#             )
#           )
#         )
#       )
#       (head): Flatten_Head(
#         (flatten): Flatten(start_dim=-2, end_dim=-1)
#         (linear): Linear(in_features=13824, out_features=24, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
# )
# module.model.backbone.W_pos True
# module.model.backbone.W_P.weight True
# module.model.backbone.W_P.bias True
# module.model.backbone.encoder.layers.0.self_attn.W_Q.weight True
# module.model.backbone.encoder.layers.0.self_attn.W_Q.bias True
# module.model.backbone.encoder.layers.0.self_attn.W_K.weight True
# module.model.backbone.encoder.layers.0.self_attn.W_K.bias True
# module.model.backbone.encoder.layers.0.self_attn.W_V.weight True
# module.model.backbone.encoder.layers.0.self_attn.W_V.bias True
# module.model.backbone.encoder.layers.0.self_attn.sdp_attn.scale False
# module.model.backbone.encoder.layers.0.self_attn.to_out.0.weight True
# module.model.backbone.encoder.layers.0.self_attn.to_out.0.bias True
# module.model.backbone.encoder.layers.0.norm_attn.1.weight True
# module.model.backbone.encoder.layers.0.norm_attn.1.bias True
# module.model.backbone.encoder.layers.0.ff.0.weight True
# module.model.backbone.encoder.layers.0.ff.0.bias True
# module.model.backbone.encoder.layers.0.ff.3.weight True
# module.model.backbone.encoder.layers.0.ff.3.bias True
# module.model.backbone.encoder.layers.0.norm_ffn.1.weight True
# module.model.backbone.encoder.layers.0.norm_ffn.1.bias True
# module.model.backbone.encoder.layers.1.self_attn.W_Q.weight True
# module.model.backbone.encoder.layers.1.self_attn.W_Q.bias True
# module.model.backbone.encoder.layers.1.self_attn.W_K.weight True
# module.model.backbone.encoder.layers.1.self_attn.W_K.bias True
# module.model.backbone.encoder.layers.1.self_attn.W_V.weight True
# module.model.backbone.encoder.layers.1.self_attn.W_V.bias True
# module.model.backbone.encoder.layers.1.self_attn.sdp_attn.scale False
# module.model.backbone.encoder.layers.1.self_attn.to_out.0.weight True
# module.model.backbone.encoder.layers.1.self_attn.to_out.0.bias True
# module.model.backbone.encoder.layers.1.norm_attn.1.weight True
# module.model.backbone.encoder.layers.1.norm_attn.1.bias True
# module.model.backbone.encoder.layers.1.ff.0.weight True
# module.model.backbone.encoder.layers.1.ff.0.bias True
# module.model.backbone.encoder.layers.1.ff.3.weight True
# module.model.backbone.encoder.layers.1.ff.3.bias True
# module.model.backbone.encoder.layers.1.norm_ffn.1.weight True
# module.model.backbone.encoder.layers.1.norm_ffn.1.bias True
# module.model.head.linear.weight True
# module.model.head.linear.bias True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch:  0
# Epoch: 1 cost time: 1.166693925857544
# Epoch: 1, Steps: 80 | Train Loss: 0.2361454 Vali Loss: 0.0901027 Test Loss: 0.1272120
# Validation loss decreased (inf --> 0.090103).  Saving model ...
# Epoch:  1
# Epoch: 2 cost time: 0.9008755683898926
# Epoch: 2, Steps: 80 | Train Loss: 0.1963798 Vali Loss: 0.0923910 Test Loss: 0.1125504
# EarlyStopping counter: 1 out of 10
# Updating learning rate to 5e-05
# Epoch:  2
# Epoch: 3 cost time: 0.9569873809814453
# Epoch: 3, Steps: 80 | Train Loss: 0.1789205 Vali Loss: 0.1258737 Test Loss: 0.1105692
# EarlyStopping counter: 2 out of 10
# Epoch:  3
# Epoch: 4 cost time: 0.9952592849731445
# Epoch: 4, Steps: 80 | Train Loss: 0.1660568 Vali Loss: 0.0912660 Test Loss: 0.1057065
# EarlyStopping counter: 3 out of 10
# Updating learning rate to 1e-05
# Epoch:  4
# Epoch: 5 cost time: 0.9954023361206055
# Epoch: 5, Steps: 80 | Train Loss: 0.1486409 Vali Loss: 0.0859234 Test Loss: 0.1011770
# Validation loss decreased (0.090103 --> 0.085923).  Saving model ...
# Epoch:  5
# Epoch: 6 cost time: 0.9783732891082764
# Epoch: 6, Steps: 80 | Train Loss: 0.1457411 Vali Loss: 0.0906279 Test Loss: 0.1019131
# EarlyStopping counter: 1 out of 10
# Updating learning rate to 5e-06
# Epoch:  6
# Epoch: 7 cost time: 1.0088887214660645
# Epoch: 7, Steps: 80 | Train Loss: 0.1443310 Vali Loss: 0.0914176 Test Loss: 0.1008150
# EarlyStopping counter: 2 out of 10
# Epoch:  7
# Epoch: 8 cost time: 1.1464042663574219
# Epoch: 8, Steps: 80 | Train Loss: 0.1411970 Vali Loss: 0.0915433 Test Loss: 0.1010911
# EarlyStopping counter: 3 out of 10
# Updating learning rate to 1e-06
# Epoch:  8
# Epoch: 9 cost time: 1.1193561553955078
# Epoch: 9, Steps: 80 | Train Loss: 0.1412245 Vali Loss: 0.0928631 Test Loss: 0.1002031
# EarlyStopping counter: 4 out of 10
# Epoch:  9
# Epoch: 10 cost time: 0.9737231731414795
# Epoch: 10, Steps: 80 | Train Loss: 0.1417527 Vali Loss: 0.0920982 Test Loss: 0.0999588
# EarlyStopping counter: 5 out of 10
# Updating learning rate to 5e-07
# Epoch:  10
# Epoch: 11 cost time: 0.9386661052703857
# Epoch: 11, Steps: 80 | Train Loss: 0.1408533 Vali Loss: 0.0933186 Test Loss: 0.1015872
# EarlyStopping counter: 6 out of 10
# Epoch:  11
# Epoch: 12 cost time: 1.1155085563659668
# Epoch: 12, Steps: 80 | Train Loss: 0.1416712 Vali Loss: 0.0942061 Test Loss: 0.1002642
# EarlyStopping counter: 7 out of 10
# Epoch:  12
# Epoch: 13 cost time: 0.9741263389587402
# Epoch: 13, Steps: 80 | Train Loss: 0.1400073 Vali Loss: 0.0946680 Test Loss: 0.1011420
# EarlyStopping counter: 8 out of 10
# Epoch:  13
# Epoch: 14 cost time: 0.9310545921325684
# Epoch: 14, Steps: 80 | Train Loss: 0.1407758 Vali Loss: 0.0929839 Test Loss: 0.0999265
# EarlyStopping counter: 9 out of 10
# Epoch:  14
# Epoch: 15 cost time: 1.1222286224365234
# Epoch: 15, Steps: 80 | Train Loss: 0.1409514 Vali Loss: 0.0937809 Test Loss: 0.1002523
# EarlyStopping counter: 10 out of 10
# Early stopping
# test shape: (207, 24, 7) (207, 24, 7)
# +-----------------------+--------------+
# |      Model Info.      |              |
# +-----------------------+--------------+
# |      Model name       |   PatchTST   |
# |        Target         |   ILITOTAL   |
# | Forecasting horizons  |      24      |
# |  Prediction features  |      MS      |
# |    transformation     |    log1p     |
# |      Data shape       |  (1038, 7)   |
# |      Train size       |     831      |
# |       Test size       |     207      |
# |      Start date       |  2002-09-30  |
# |       End date        |  2024-08-12  |
# | Forecast tensor shape | (207, 24, 7) |
# |       QoF mode        |    single    |
# |      Validation       |  TrainNTest  |
# |     Total params      |   1139480    |
# +-----------------------+--------------+
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/205 [00:00<?, ?it/s]
#   0%|          | 0/205 [00:00<?, ?it/s]
#   0%|          | 0/205 [00:00<?, ?it/s]
#   0%|          | 0/205 [00:00<?, ?it/s]
#   0%|          | 0/205 [00:00<?, ?it/s]
#   0%|          | 0/205 [00:00<?, ?it/s]
#   0%|          | 0/205 [00:00<?, ?it/s]
# Total time:0.17792081832885742 seconds.
#
# Quality of Fit (QoF) for PatchTST - Task: MS - Target: ILITOTAL
# +------+-----+----------------+----------------+--------------+----------------+
# |  h   |  n  | MSE Normalized | MAE Normalized | MAE Original | sMAPE Original |
# +------+-----+----------------+----------------+--------------+----------------+
# |  1   | 184 |     0.0232     |     0.1129     |  6834.9231   |    11.2344     |
# |  2   | 184 |     0.0424     |     0.1506     |  9181.3641   |    14.9253     |
# |  3   | 184 |     0.0599     |     0.1828     |  11046.7845  |    18.0622     |
# |  4   | 184 |     0.0715     |     0.199      |  11756.7962  |     19.61      |
# |  5   | 184 |     0.0879     |     0.2211     |  12988.7497  |    21.7299     |
# |  6   | 184 |     0.1127     |     0.2569     |  14456.3288  |    25.1746     |
# |  7   | 184 |     0.1215     |     0.2642     |  14818.2485  |    25.8316     |
# |  8   | 184 |     0.1362     |     0.2722     |  15391.8909  |    26.5031     |
# |  9   | 184 |     0.1504     |     0.3026     |  16801.9285  |    29.5069     |
# |  10  | 184 |     0.1615     |     0.304      |  16660.0756  |    29.5306     |
# |  11  | 184 |     0.1605     |     0.309      |  16865.9622  |    30.0679     |
# |  12  | 184 |     0.1741     |     0.3153     |  17231.786   |     30.572     |
# |  13  | 184 |     0.1681     |     0.2989     |  16139.807   |    28.9373     |
# |  14  | 184 |     0.1691     |     0.3045     |  16715.492   |     29.509     |
# |  15  | 184 |     0.1771     |     0.3116     |  16873.1256  |    30.1743     |
# |  16  | 184 |     0.1807     |     0.3243     |  17539.2606  |    31.4419     |
# |  17  | 184 |     0.1834     |     0.3334     |  17774.3673  |    32.3573     |
# |  18  | 184 |     0.1921     |     0.3334     |  18131.7567  |    32.2629     |
# |  19  | 184 |     0.201      |     0.3434     |  18540.323   |    33.2124     |
# |  20  | 184 |     0.1977     |     0.3359     |  18252.0943  |    32.4822     |
# |  21  | 184 |     0.1949     |     0.3456     |  18597.752   |    33.5082     |
# |  22  | 184 |     0.2007     |     0.3443     |  18381.8552  |    33.3161     |
# |  23  | 184 |     0.2068     |     0.3387     |  18338.0369  |     32.658     |
# |  24  | 184 |     0.2124     |     0.3427     |  18578.2893  |    33.0221     |
# | Avg. |     |     0.1494     |     0.2853     |  15745.7082  |    27.7346     |
# +------+-----+----------------+----------------+--------------+----------------+
